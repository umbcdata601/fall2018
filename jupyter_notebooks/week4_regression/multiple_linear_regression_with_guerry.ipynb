# %%
import pandas
import matplotlib.pylab as plt
pandas.__version__
# Out:
# '0.23.4'

# %% [markdown]
# data description:
# http://vincentarelbundock.github.io/Rdatasets/doc/HistData/Guerry.html<BR>
# and http://euclid.psych.yorku.ca/SCS/Gallery/guerry/guerrydat.html
#
# data source: https://github.com/vincentarelbundock/Rdatasets/blob/master/csv/HistData/Guerry.csv

# %%
df = pandas.read_csv('guerry.csv')
df.shape
# Out:
# (86, 24)

# %%
df.head()
# Out:
#    Unnamed: 0  dept Region    Department  Crime_pers  Crime_prop  Literacy  \
# 0           1     1      E           Ain       28870       15890        37
# 1           2     2      N         Aisne       26226        5521        51
# 2           3     3      C        Allier       26747        7925        13
# 3           4     4      E  Basses-Alpes       12935        7289        46
# 4           5     5      E  Hautes-Alpes       17488        8174        69
#
#    Donations  Infants  Suicides   ...    Crime_parents  Infanticide  \
# 0       5098    33120     35039   ...               71           60
# 1       8901    14572     12831   ...                4           82
# 2      10973    17044    114121   ...               46           42
# 3       2733    23018     14238   ...               70           12
# 4       6962    23076     16171   ...               22           23
#
#    Donation_clergy  Lottery  Desertion  Instruction  Prostitutes  Distance  \
# ...

# %% [markdown]
# The above layout contains a preview of the dataframe, but isn't readable due to orientation
#
# Transposing the dataframe allows viewing of all the columns.

# %%
df.T
# Out:
#                       0       1        2             3             4   \
# Unnamed: 0             1       2        3             4             5
# dept                   1       2        3             4             5
# Region                 E       N        C             E             E
# Department           Ain   Aisne   Allier  Basses-Alpes  Hautes-Alpes
# Crime_pers         28870   26226    26747         12935         17488
# Crime_prop         15890    5521     7925          7289          8174
# Literacy              37      51       13            46            69
# Donations           5098    8901    10973          2733          6962
# Infants            33120   14572    17044         23018         23076
# Suicides           35039   12831   114121         14238         16171
# MainCity           2:Med   2:Med    2:Med          1:Sm          1:Sm
# Wealth                73      22       61            76            83
# ...

# %% [markdown]
# For each column, what is the type of entry?

# %%
df.dtypes
# Out:
# Unnamed: 0           int64
# dept                 int64
# Region              object
# Department          object
# Crime_pers           int64
# Crime_prop           int64
# Literacy             int64
# Donations            int64
# Infants              int64
# Suicides             int64
# MainCity            object
# Wealth               int64
# Commerce             int64
# Clergy               int64
# Crime_parents        int64
# Infanticide          int64
# Donation_clergy      int64
# Lottery              int64
# Desertion            int64
# Instruction          int64
# Prostitutes          int64
# Distance           float64
# Area                 int64
# Pop1831            float64
# dtype: object

# %% [markdown]
# For a better sense of the values, use describe:

# %%
df.describe()
# Out:
#        Unnamed: 0        dept    Crime_pers    Crime_prop   Literacy  \
# count   86.000000   86.000000     86.000000     86.000000  86.000000
# mean    43.500000   46.883721  19754.406977   7843.058140  39.255814
# std     24.969982   30.426157   7504.703073   3051.352839  17.364051
# min      1.000000    1.000000   2199.000000   1368.000000  12.000000
# 25%     22.250000   24.250000  14156.250000   5933.000000  25.000000
# 50%     43.500000   45.500000  18748.500000   7595.000000  38.000000
# 75%     64.750000   66.750000  25937.500000   9182.250000  51.750000
# max     86.000000  200.000000  37014.000000  20235.000000  74.000000
#
#           Donations       Infants       Suicides     Wealth   Commerce  \
# count     86.000000     86.000000      86.000000  86.000000  86.000000
# mean    7075.546512  19049.906977   36522.604651  43.500000  42.802326
# std     5834.595216   8820.233546   31312.532649  24.969982  25.028370
# ...

# %% [markdown]
# The 21 columns make the table too long, so let's transpose the table

# %%
df.describe().T
# Out:
#                  count          mean           std     min        25%  \
# Unnamed: 0        86.0     43.500000     24.969982     1.0     22.250
# dept              86.0     46.883721     30.426157     1.0     24.250
# Crime_pers        86.0  19754.406977   7504.703073  2199.0  14156.250
# Crime_prop        86.0   7843.058140   3051.352839  1368.0   5933.000
# Literacy          86.0     39.255814     17.364051    12.0     25.000
# Donations         86.0   7075.546512   5834.595216  1246.0   3446.750
# Infants           86.0  19049.906977   8820.233546  2660.0  14299.750
# Suicides          86.0  36522.604651  31312.532649  3460.0  15463.000
# Wealth            86.0     43.500000     24.969982     1.0     22.250
# Commerce          86.0     42.802326     25.028370     1.0     21.250
# Clergy            86.0     43.430233     24.999549     1.0     22.250
# Crime_parents     86.0     43.500000     24.969982     1.0     22.250
# ...

# %% [markdown]
# although the data types and stats are interesting, I want a better sense of what the distribution is for each variable

# %%
fig = plt.figure(figsize = (15,20))
ax = fig.gca()
_=df.hist(ax = ax)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2961: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %% [markdown]
# While distributions are a better visualization and can yield stories, there are even better options...

# %%
import seaborn
seaborn.__version__
# Out:
# '0.9.0'

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# https://python-graph-gallery.com/111-custom-correlogram/

# %%
seaborn.pairplot(df, kind="scatter")
plt.show()

# %% [markdown]
# Because there are so many numeric columns, let's focus on a subset of the dataframe

# %%
seaborn.pairplot(df[['Crime_pers','Literacy','Infants','Suicides','Area']], kind="scatter")
plt.show()

# %% [markdown]
# For the lazy data scientist, there are ways to easily get simple linear fits of each pair.
#
# <BR>
# <BR>
# <BR>
# <BR>
#
#
# <img src="lazy_programmer.jpg">

# %%
seaborn.pairplot(df[['Crime_pers','Literacy','Infants','Suicides','Area']], kind="reg")
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# Reminder of hidden code here

# %%
for this_column in df.columns:
    print("==== ",this_column,"has",df[this_column].nunique(),"unique entries ====")
    print(df[this_column].value_counts().head(10))
# Out:
# ====  Unnamed: 0 has 86 unique entries ====
# 86    1
# 32    1
# 24    1
# 25    1
# 26    1
# 27    1
# 28    1
# 29    1
# 30    1
# 31    1
# Name: Unnamed: 0, dtype: int64
# ====  dept has 86 unique entries ====
# 200    1
# 34     1
# 26     1
# 27     1
# 28     1
# 29     1
# 30     1
# 31     1
# 32     1
# 33     1
# Name: dept, dtype: int64
# ====  Region has 5 unique entries ====
# C    17
# E    17
# N    17
# S    17
# W    17
# Name: Region, dtype: int64
# ====  Department has 86 unique entries ====
# Haute-Marne        1
# Aube               1
# Tarn-et-Garonne    1
# Eure-et-Loir       1
# Meurthe            1
# Doubs              1
# Cote-d'Or          1
# Lot                1
# Mayenne            1
# Vaucluse           1
# Name: Department, dtype: int64
# ====  Crime_pers has 85 unique entries ====
# 18642    2
# 25087    1
# 21934    1
# 24096    1
# 15010    1
# 11560    1
# 17577    1
# 16170    1
# 28331    1
# 8236     1
# Name: Crime_pers, dtype: int64
# ...

# %% [markdown]
# Without any understanding of the columns, we can calculate the correlation of each pair

# %%
df.corr()
# Out:
#                  Unnamed: 0      dept  Crime_pers  Crime_prop  Literacy  \
# Unnamed: 0         1.000000  0.923024   -0.118008   -0.283929  0.092906
# dept               0.923024  1.000000   -0.201356   -0.288435  0.100865
# Crime_pers        -0.118008 -0.201356    1.000000    0.274774 -0.035535
# Crime_prop        -0.283929 -0.288435    0.274774    1.000000 -0.366847
# Literacy           0.092906  0.100865   -0.035535   -0.366847  1.000000
# Donations          0.062214  0.271416   -0.035825   -0.132676 -0.127631
# Infants           -0.072540 -0.031004   -0.044467    0.267392 -0.406229
# Suicides          -0.177179 -0.151064   -0.130263    0.519594 -0.373466
# Wealth            -0.075541 -0.079439   -0.117098    0.459040 -0.275816
# Commerce          -0.026082  0.045560    0.046991    0.411277 -0.580925
# Clergy             0.151215  0.059506    0.255535   -0.067345 -0.171404
# Crime_parents     -0.156243 -0.068367   -0.195369    0.355513 -0.204481
# ...

# %% [markdown]
# ## Plot the data points for 3 randomly selected columns

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# enables rotation of 3D images
# %matplotlib notebook

# %%
print('Desertion  max:',max(list(df['Desertion'])),'min:',min(list(df['Desertion'])))
print('Literacy  max:',max(list(df['Literacy'])),'min:',min(list(df['Literacy'])))
print('Area  max:',max(list(df['Area'])),'min:',min(list(df['Area'])))
# Out:
# Desertion  max: 86 min: 1
# Literacy  max: 74 min: 12
# Area  max: 10000 min: 762

# %% [markdown]
# https://pythonprogramming.net/3d-graphing-pandas-matplotlib/

# %% [markdown]
# Military disertion, ratio of the number of young soldiers accused of desertion to the force of the military contingent, minus the deficit produced by the insufficiency of available billets– Average of the years 1825-1827.
#
# Percent of military conscripts who can read and write.
#
# Area of region of France

# %%
ax = plt.figure().gca(projection='3d')
ax.scatter(df["Desertion"], df['Literacy'], df['Area'])
ax.set_xlabel('Desertion')
ax.set_ylabel('Literacy')
ax.set_zlabel('Area')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## linear regression using 2 features

# %% [markdown]
# http://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html

# %%
from sklearn.linear_model import LinearRegression

# %%
X = df[["Desertion","Literacy"]]
y = df["Area"]

# %% [markdown]
# Claim: desertion rate and literacy can be used to predict the area of a region of France
#
# _To revisit later_: how would we test the validity of this claim?

# %%
model = LinearRegression().fit(X,y)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.5/lib/python3.5/site-packages/sklearn/linear_model/base.py:509: RuntimeWarning: internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
#   linalg.lstsq(X, y)

# %%
model.coef_
# Out:
# array([  8.9567911 , -23.62193453])

# %%
coeff_df = pandas.DataFrame(model.coef_, X.columns, columns=['Coefficient'])  
coeff_df
# Out:
#            Coefficient
# Desertion     8.956791
# Literacy    -23.621935

# %%
model.intercept_
# Out:
# 6684.666226242779

# %% [markdown]
# ### plot the plane

# %%
import numpy as np

np.linspace(0,1,10)
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])

# %%
# https://stackoverflow.com/questions/48335279/given-general-3d-plane-equation-how-can-i-plot-this-in-python-matplotlib

des = np.linspace(0,90,10)
lit = np.linspace(0,90,10)

D,L = np.meshgrid(des,lit)
A = model.intercept_ + model.coef_[0]*D + model.coef_[1]*L

fig = plt.figure()
ax = fig.gca(projection='3d')

surf = ax.plot_surface(D,L,A)

_=ax.set_xlabel('Desertion')
_=ax.set_ylabel('Literacy')
_=ax.set_zlabel('Area')
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# ## plot plane and data points

# %%
ax = plt.figure().gca(projection='3d')
ax.scatter(df["Desertion"], df['Literacy'], df['Area'])

surf = ax.plot_surface(D,L,A)

_=ax.set_xlabel('Desertion')
_=ax.set_ylabel('Literacy')
_=ax.set_zlabel('Area')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# _To revisit later_: how would we conceptualize higher dimensions of linear fit?
